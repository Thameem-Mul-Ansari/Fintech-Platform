# %%
pip install openai pytube
# Out:
# Requirement already satisfied: openai in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (0.27.7)
# Requirement already satisfied: pytube in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (15.0.0)
# Requirement already satisfied: requests>=2.20 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: colorama in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tqdm->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to c:\users\thame\appdata\local\temp\pip-req-build-b66ld5rz
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numba in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (0.57.1)
# Requirement already satisfied: numpy in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (1.24.3)
# Requirement already satisfied: torch in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (2.0.1)
# Requirement already satisfied: tqdm in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (4.65.0)
# Requirement already satisfied: more-itertools in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (10.1.0)
# Requirement already satisfied: tiktoken in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from openai-whisper==20231117) (0.4.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from numba->openai-whisper==20231117) (0.40.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tiktoken->openai-whisper==20231117) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: filelock in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from torch->openai-whisper==20231117) (3.12.0)
# Requirement already satisfied: typing-extensions in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from torch->openai-whisper==20231117) (4.6.2)
# Requirement already satisfied: sympy in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from torch->openai-whisper==20231117) (2.8.8)
# Requirement already satisfied: jinja2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from torch->openai-whisper==20231117) (3.1.2)
# Requirement already satisfied: colorama in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tqdm->openai-whisper==20231117) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch->openai-whisper==20231117) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\thame\AppData\Local\Temp\pip-req-build-b66ld5rz'
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install typing-extensions
# Out:
# Requirement already satisfied: typing-extensions in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (4.6.2)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install cohere
# Out:
# Requirement already satisfied: cohere in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (4.45)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (3.8.4)
# Requirement already satisfied: backoff<3.0,>=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (2.2.1)
# Requirement already satisfied: fastavro<2.0,>=1.8 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (1.9.3)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (6.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from cohere) (2.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from importlib_metadata<7.0,>=6.0->cohere) (3.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.25.0->cohere) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.25.0->cohere) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install tensorflow-probability
# Out:
# Requirement already satisfied: tensorflow-probability in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (0.23.0)
# Requirement already satisfied: absl-py in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (1.4.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (1.24.3)
# Requirement already satisfied: decorator in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (3.0.0)
# Requirement already satisfied: gast>=0.3.2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: dm-tree in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-probability) (0.1.8)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import openai
import whisper
import pandas as pd
from pytube import YouTube

# %%
COMPLETIONS_MODEL = "text-davinci-003"
EMBEDDINGS_MODEL = "text-embedding-ada-002"
openai.api_key = "your_openai_api_key"

# %%
model = whisper.load_model('base')

# %%
import threading
from pytube import YouTube
import os

video_urls = [
    "https://www.youtube.com/watch?v=0z49u_b6PmE",
    "https://www.youtube.com/watch?v=IDGnZ2AErBg",
    "https://www.youtube.com/watch?v=rBm9y4NuxlY",
    "https://www.youtube.com/watch?v=oazzjOjJXKQ",
    "https://www.youtube.com/watch?v=Gy0A-e1xNco"
]

def download_video(video_url):
    try:
        yt = YouTube(video_url)
        stream = yt.streams.filter(file_extension='mp4').first()
        if stream:
            download_path = os.path.join("videos", yt.title + ".mp4")
            stream.download(output_path="videos", filename=yt.title)
            print(f"Downloaded: {yt.title}.mp4")
        else:
            print(f"No mp4 stream available for {yt.title}")
    except Exception as e:
        print(f"Error downloading {video_url}: {str(e)}")

if not os.path.exists("videos"):
    os.makedirs("videos")

threads = []
for video_url in video_urls:
    thread = threading.Thread(target=download_video, args=(video_url,))
    threads.append(thread)
    thread.start()

for thread in threads:
    thread.join()

print("All downloads completed.")
# Out:
# Error downloading https://www.youtube.com/watch?v=rBm9y4NuxlY: [Errno 2] No such file or directory: 'e:\\pec\\videos\\Is a 90/10 Portfolio Too Risky For Retirement? | Portfolio Rescue'
# Error downloading https://www.youtube.com/watch?v=oazzjOjJXKQ: [Errno 22] Invalid argument: "e:\\pec\\videos\\Why You Shouldn't Max Out Your 401k | Portfolio Rescue"
# Error downloading https://www.youtube.com/watch?v=Gy0A-e1xNco: [Errno 22] Invalid argument: 'e:\\pec\\videos\\How Do I Teach My Kids About Money? | Portfolio Rescue'Error downloading https://www.youtube.com/watch?v=0z49u_b6PmE: [Errno 22] Invalid argument: 'e:\\pec\\videos\\Should I Invest in Rental Properties? | Portfolio Rescue'
#
# Error downloading https://www.youtube.com/watch?v=IDGnZ2AErBg: [Errno 22] Invalid argument: 'e:\\pec\\videos\\Where Should I Save For My Down Payment? | Portfolio Rescue'
# All downloads completed.

# %%
output = model.transcribe("videos/portfolio_rescue.mp4")
# Out:
# c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
output['text']
# Out:
# " Welcome back to Portfolio Rescue. Our show will take questions straight from you, the viewer. Remember if you have a question for us, ask the Com Mount Show at gmail.com. Last week we had Barry Rittholz on the show, the namesake of our firm. Barry had a lot of interesting things to say about writing and producing content and blogging. He's been doing this for a couple of decades now. I mentioned with Barry that I answered questions. When I started my blog, my whole reason for doing it was answering questions for friends and family because I was sick of them asking me because I was the finance investment guy. I tip big at two questions from my high school friends, especially the high school and college friends, text messages. One is should I buy or sell this stock? What should I do with this here? Is this a good buy? Is this a good sell? And two, is this going to get worse? I hear from people way more and things are getting worse. Things right now are getting worse. I have a question. I think our first one we're going to do today is actually from someone who texted me this week, one of my friends. We're going to use that. What do we get here, Duncan? Alright, cool. Before we get started, I just want to say for those who haven't watched, you have to watch the latest animal spirits. It's episode 247. There's a clip in there of Ben scoring a touchdown at what was the stadium? The Silver Dome in Detroit, Michigan, which is not there anymore. I think it's been torn down, but that was the old stadium before they had it. My glory days, I played there a couple times for the state championship. That was like 98, 99. Yeah. Everyone needs to watch that. But first I had a football question for you, which is, I've always wondered when I see you evading tackles in that long run, would you rather see someone coming to tackle you or not know that they're coming? Oh, definitely see them. Okay. The reason I asked is because of the car crash thing, people say, if you tense up, that's when it hurts the most and you get injured the most. So I didn't know if it's preferable to just be tackled and not know. Okay, yeah. I think preparing for one, it's kind of unlike the stock market, right? You'd rather be prepared for a downturn than get hit from the side, right? Okay, cool, cool. I ran cross-country, so we don't tackle. Okay. Okay, so first up, today we have a short and sweet one. Inflation was already out of control. Now the war has made gas prices spike. How does this not end in recession? Yeah, I think this is a question a lot of people are asking these days. And unfortunately, like the odds of a recession are much higher now than they were called two to an F weeks ago. I think you'd have to be pretty dense to not at least think that. It's obviously impossible to predict these things with 100% certainty, but I would almost be surprised if we didn't have some sort of minor economic contraction because of this. And it's not just the US, right? This thing will probably be global, and I'm guessing the US will probably fare the best out of most developed nations. So John thrilled this chart of electricity and natural gas. This is from Michael Sumbleset, JP Morgan. He compares electricity prices and natural gas prices between some countries in Europe and then the US. You can see the spike in Europe is just massive. And they're far more dependent on Russia for some of their commodities. And their prices there were much higher to begin with. It's funny. We're complaining about $4 gas here in the US, but in Europe, people have been paying well over that price for a long time now. They already have a lot more and they do it in leaders. So I can't do the actual conversion in my head, but let's just say it's higher. It is important to note that inflation doesn't always cause a recession, but every inflationary spike in history has only been alleviated by a recession, right? So what happens to get that inflation back down? Unfortunately, every time it's a r ...

# %%
import csv

df = pd.DataFrame(columns=['episode', 'url', 'start_timestamp', 'start', 'end', 'question', 'context'])

i = 0

with open('financial_advisor.csv', encoding='ISO-8859-1') as csv_file:
    reader = csv.reader(csv_file)

    next(reader)

    for row in reader:
        episode, url, questions = row
        question_list = questions.split("\n")

        for question in question_list:
            pieces = question.split('-')
            timestamp = pieces[0]
            minutes, seconds = timestamp.split(':')
            seconds = int(seconds) + (int(minutes.lstrip()) * 60)

            df.loc[i] = [episode, url, timestamp, seconds, seconds, " ".join(pieces[1:]), ""]

            try:
                df.loc[i-1]['end'] = df.loc[i]['start']
            except:
                print(f"skipping row {i} because there is no previous row")

            i += 1

            df['end'][df['end'] < df['start']] = 0
            df['end'][df['start'] == df['end']] = 0

df.to_csv("questions.csv")
# Out:
# skipping row 0 because there is no previous row
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i-1]['end'] = df.loc[i]['start']
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['end'] < df['start']] = 0
# C:\Users\thame\AppData\Local\Temp\ipykernel_18812\1124201371.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end'][df['start'] == df['end']] = 0

# %%
import pandas as pd

df = pd.read_csv('questions.csv')
df
# Out:
#      Unnamed: 0     episode                                          url  \
# 0             0   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 1             1   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 2             2   Episode 1  https://www.youtube.com/watch?v=0z49u_b6PmE
# 3             3   Episode 2  https://www.youtube.com/watch?v=IDGnZ2AErBg
# 4             4   Episode 2  https://www.youtube.com/watch?v=IDGnZ2AErBg
# ..          ...         ...                                          ...
# 323         323  Episode 67  https://www.youtube.com/watch?v=vh7XLSLCpKQ
# 324         324  Episode 67  https://www.youtube.com/watch?v=vh7XLSLCpKQ
# 325         325  Episode 67  https://www.youtube.com/watch?v=vh7XLSLCpKQ
# 326         326  Episode 67  https://www.youtube.com/watch?v=vh7XLSLCpKQ
# 327         327  Episode 67  https://www.youtube.com/watch?v=vh7XLSLCpKQ
#
#     start_timestamp  start  end  \
# 0            03:07     187    0
# 1            06:55     415    0
# 2            11:09     669    0
# 3            01:04      64    0
# 4            06:06     366    0
# ..              ...    ...  ...
# 323          03:00     180    0
# 324          08:44     524    0
# 325          16:00     960    0
# 326          20:32    1232    0
# 327          28:25    1705    0
#
#                                               question  context
# 0     What's the best way to reallocate a portfolio...      NaN
# 1     What do I do once I cross the Roth IRA income...      NaN
# 2     Once I have maxed out my retiremenet accounts...      NaN
# 3                                 Saving vs. Investing      NaN
# 4     If Baby Boomers are shifting from net investo...      NaN
# ..                                                 ...      ...
# 323             Did VCs cause the bank run on Twitter?      NaN
# 324                 What happens if a brokerage fails?      NaN
# 325                                              FHLB.      NaN
# 326                       Are Money Market Funds safe?      NaN
# 327   Did this banking crisis make a recession more...      NaN
#
# [328 rows x 8 columns]

# %%
episode = df[df['episode'] == 'Episode 22'].copy()
episode
# Out:
#     Unnamed: 0     episode                                          url  \
# 83          83  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 84          84  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 85          85  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 86          86  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 87          87  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 88          88  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 89          89  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 90          90  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 91          91  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
#
#    start_timestamp  start  end  \
# 83          01:58     118    0
# 84          03:30     210    0
# 85          05:16     316    0
# 86          10:18     618    0
# 87          11:57     717    0
# 88          13:25     805    0
# 89          14:39     879    0
# 90          17:19    1039    0
# 91          21:15    1275    0
#
#                                              question  context
# 83   How does the fed raising interest rates fight...      NaN
# 84   What particular sectors/names do you find mos...      NaN
# 85   What will bring more value in the long run fo...      NaN
# 86   Would you recommend focusing on paying off my...      NaN
# 87                             Paying off a mortgage.      NaN
# 88            What happens when the Fed raises rates?      NaN
# 89   Iâm 44 and have a net worth of around $425K...      NaN
# 90   What are some good questions to ask when sele...      NaN
# 91    At interest rates so low, should I instead t...      NaN

# %%
def is_part_of_question(segment, start, end):
    if segment['start'] > start:
      if segment['end'] < end or end == 0:
          return True

    return False

def get_question_context(row):
     global output

     question_segments = list(filter(lambda segment: is_part_of_question(segment, row['start'], row['end']), output['segments']))
     # include question from timestamp in the context
     context = row['question']
     for segment in question_segments:
         context += segment['text']

     return context

episode['context'] = episode.apply(get_question_context, axis=1)

episode
# Out:
#     Unnamed: 0     episode                                          url  \
# 83          83  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 84          84  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 85          85  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 86          86  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 87          87  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 88          88  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 89          89  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 90          90  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 91          91  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
#
#    start_timestamp  start  end  \
# 83          01:58     118    0
# 84          03:30     210    0
# 85          05:16     316    0
# 86          10:18     618    0
# 87          11:57     717    0
# 88          13:25     805    0
# 89          14:39     879    0
# 90          17:19    1039    0
# 91          21:15    1275    0
#
#                                              question  \
# 83   How does the fed raising interest rates fight...
# 84   What particular sectors/names do you find mos...
# 85   What will bring more value in the long run fo...
# 86   Would you recommend focusing on paying off my...
# 87                             Paying off a mortgage.
# 88            What happens when the Fed raises rates?
# 89   Iâm 44 and have a net worth of around $425K...
# 90   What are some good questions to ask when sele...
# 91    At interest rates so low, should I instead t...
#
#                                               context
# 83   How does the fed raising interest rates fight...
# 84   What particular sectors/names do you find mos...
# 85   What will bring more value in the long run fo...
# 86   Would you recommend focusing on paying off my...
# 87   Paying off a mortgage. I don't want to take t...
# 88   What happens when the Fed raises rates? Is th...
# 89   Iâm 44 and have a net worth of around $425K...
# 90   What are some good questions to ask when sele...
# 91    At interest rates so low, should I instead t...

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (3.7.1)Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip uninstall plotly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from plotly) (23.1)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from tenacity import retry, wait_fixed, stop_after_delay
from openai.embeddings_utils import get_embedding

@retry(wait=wait_fixed(20), stop=stop_after_delay(600))  
def get_embedding_with_retry(text):
    return get_embedding(text, engine='text-embedding-ada-002')

episode['embedding'] = episode['context'].apply(lambda row: get_embedding_with_retry(row))
episode.to_csv('question_embeddings.csv')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\embeddings_utils.py:23, in get_embedding(text, engine, **kwargs)
#      21 text = text.replace("\n", " ")
# ---> 23 return openai.Embedding.create(input=[text], engine=engine, **kwargs)["data"][0]["embedding"]
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      32 try:
# ---> 33     response = super().create(*args, **kwargs)
#      35     # If a user specifies base64, we'll just return the encoded string.
#      36     # This is only for the default case.
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     138 (
#     139     deployment_id,
#     140     engine,
#    (...)
#     150     api_key, api_base, api_type, api_version, organization, **params
#     151 )
# --> 153 response, _, api_key = requestor.request(
#     154     "post",
#     155     url,
#     156     params=params,
#     157     headers=headers,
#     158     stream=stream,
#     159     request_id=request_id,
#     160     request_timeout=request_timeout,
#     161 )
#     163 if stream:
#     164     # must be an iterator
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     220 result = self.request_raw(
#     221     method.lower(),
#     222     url,
#    (...)
#     228     request_timeout=request_timeout,
#     229 )
# --> 230 resp, got_stream = self._interpret_response(result, stream)
#     231 return resp, got_stream, self.api_key
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# AuthenticationError: Incorrect API key provided: sk-ccNir***************************************yDRD. You can find your API key at https://platform.openai.com/account/api-keys.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# Cell In[20], line 6, in get_embedding_with_retry(text)
#       4 @retry(wait=wait_fixed(20), stop=stop_after_delay(600))
#       5 def get_embedding_with_retry(text):
# ----> 6     return get_embedding(text, engine='text-embedding-ada-002')
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:326, in BaseRetrying.iter(self, retry_state)
#     325         raise retry_exc.reraise()
# --> 326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# RetryError: RetryError[<Future at 0x23e2fd3ecb0 state=finished raised AuthenticationError>]
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[20], line 8
#       4 @retry(wait=wait_fixed(20), stop=stop_after_delay(600))
#       5 def get_embedding_with_retry(text):
#       6     return get_embedding(text, engine='text-embedding-ada-002')
# ----> 8 episode['embedding'] = episode['context'].apply(lambda row: get_embedding_with_retry(row))
#       9 episode.to_csv('question_embeddings.csv')
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[20], line 8, in <lambda>(row)
#       4 @retry(wait=wait_fixed(20), stop=stop_after_delay(600))
#       5 def get_embedding_with_retry(text):
#       6     return get_embedding(text, engine='text-embedding-ada-002')
# ----> 8 episode['embedding'] = episode['context'].apply(lambda row: get_embedding_with_retry(row))
#       9 episode.to_csv('question_embeddings.csv')
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:326, in BaseRetrying.iter(self, retry_state)
#     324     if self.reraise:
#     325         raise retry_exc.reraise()
# --> 326     raise retry_exc from fut.exception()
#     328 if self.wait:
#     329     sleep = self.wait(retry_state)
#
# RetryError: RetryError[<Future at 0x23e2fd3ea40 state=finished raised RetryError>]

# %%
from openai.embeddings_utils import cosine_similarity

question = "Should I buy a house with cash?"
question_vector = get_embedding(question, engine='text-embedding-ada-002')

episode["similarities"] = episode['embedding'].apply(lambda x: cosine_similarity(x, question_vector))
episode = episode.sort_values("similarities", ascending=False).head(4)

episode
# Out:
#     Unnamed: 0     episode                                          url  \
# 91          91  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 86          86  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 87          87  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
# 84          84  Episode 22  https://www.youtube.com/watch?v=OYxhrPdZdog
#
#    start_timestamp  start  end  \
# 91          21:15    1275    0
# 86          10:18     618    0
# 87          11:57     717    0
# 84          03:30     210    0
#
#                                              question  \
# 91    At interest rates so low, should I instead t...
# 86   Would you recommend focusing on paying off my...
# 87                             Paying off a mortgage.
# 84   What particular sectors/names do you find mos...
#
#                                               context  \
# 91    At interest rates so low, should I instead t...
# 86   Would you recommend focusing on paying off my...
# 87   Paying off a mortgage. city or out of state. ...
# 84   What particular sectors/names do you find mos...
#
#                                             embedding  similarities
# 91  [-0.0266269501298666, -0.018693311139941216, 0...      0.855404
# 86  [-0.017988426610827446, -0.00646671699360013, ...      0.803571
# 87  [-0.005947297438979149, -0.0017322226194664836...      0.796878
# 84  [-0.001250185421667993, -0.010448704473674297,...      0.790833

# %%
episode.to_csv("sorted.csv")

# %%
context = []
for i, row in episode.iterrows():
  context.append(row['context'])

context
# Out:
# ['  At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market?',
#  " Paying off a mortgage. city or out of state. That's tough. So do you really want to be someone who's running a rental operation? And the other thing is, they're not huge pools of capital coming in here that weren't there before, that can do this much more efficiently than individuals. So I know that there are individuals who can do this. I would just caution people to understand that this is true active investing, active in the form of you have to do a lot of stuff. There's a lot of costs involved. And it's probably not going to be easy. And one blown something in the house and you're spending on it and you lose all your income for the whole year. Yeah, you're running a business. That's it. I agree. I do, we as a firm, advise folks on some of these decisions, but I also play this game. I'm a client too. I own a five unit rental property in suburban New York. And there are really two big things I want to say on this. Number one is that I think the listeners right, I think over the long term, real estate is an awesome long term investing opportunity. But like everything in investing, it's less about what you buy and it's probably more about what you pay. And so the listeners thinking about this, I think soberly, Ben, I think correctly identifies the what's going on broadly in the market. The reality is real estate is local. And so if you can find a local opportunity, if you can find somebody that you have a relationship with that potentially wants to help you out, that's a great thing to jump in on. If you're focused on, let's say, 10 years or more, we all know the guy who's dad bought a house in Brooklyn in 1975 for $5,000, right? And he sold it last year for a half million. Therefore his return was a hundred X. No, it wasn't. Along the way, Ben, you're right. He had to replace a roof at some point for $20,000. The plumbing had to be replaced. And so the taxes are... Well, put in your situation, how do you find tenants every year? So it's rough. And that means for me putting it out on Craigslist and if that doesn't work, I need to go find a broker, right? And then I owe them a first month's rent that choose into my net operating profit there in year one, meaning every tenant I sign a new tenant is in that loss for that first year, right? And Ben, I'm glad you brought that up because it's work. Real estate investing is work unless you're outsourcing this stuff, which again eats in your profit. I have five tenants. That means I have five clients that I need to sit down with at least once a year to discuss their lease. There are broken toilets that happen at two in the morning on a random Tuesday. And if my plumbers are not picking up the phone and there's water pouring out over my floor, it's up to me to get off my butt, get in my car at two in the morning and drive out there and get that fixed. So my advice is be prepared to run a business. This is a part-time job. Pay attention to cost unless about other variables like if everyone else is doing it. And you really have to be in this for the long haul. Yeah. All right. So that's a great question for you guys. And I'm going through personally. This is not coming from a listener. This is not coming from you. This is me. I've had some issues with my landscape recently. They're having, I feel for them because they're having a labor shortage. They have been communicating with me very well. So we needed to replace some trees in the backyard because they kept dying. Every single summer, these trees die and every summer they tell us a new type of tree that's going to go and that's going to fix this problem. Surprisingly, they said the trees are getting too much water. I don't know if that's like kind of like your car mechanic making up a part and telling you about, but sure, too much water. Your car's getting too much gasping. So yeah. So in May, they told us, we're going to replace these trees where we got some nice birch trees. We're going to bring back. It's going to be beautiful.  ...
#  " What particular sectors/names do you find most compelling for a young investor with a 35 40 year time horizon? But what's the best way for him to do this? A one time move to stocks or index funds, move his money and chunk server the course of the next year. Any advice would be appreciated. This is an interesting one because so many people today are worried about others taking too much advice or too much risk, I should say. So it's kind of interesting to think through why would this person be so conservative? Because last year the stock market was up almost 20%. Crypto was up an ungodly amount. Even bonds were up. So 2% is pretty tough to stomach. So there's reasons people don't take a lot of risk. One could be they just don't understand how the markets work. Maybe they're too scared. Maybe they're getting bad advice from their advisor here. Maybe they're just scared of losing money in the markets. So they've already lost money in their scarred from the past. The way that I look at it as a young person with decades and decades ahead of them, it's virtually impossible to take too much risk in your portfolio because your two biggest assets are human capital in time. So you have this power of compounding and your future earnings power as this huge tailwind. The problem is there's a huge difference between the right advice and advice that actually works. So if this person is scared of losing money, which it can happen, I wanted to read something from one of my favorite books. It's called Where the Customers Yots. It's one of the best titled books of all time, as well as probably the funniest investment book ever read ever written in as written in 1940. Now that's a pretty short list of funny investment books, but I just wanted to read this one passage because I think it really ties into this question. Like all of life's rich emotional experiences, the full flavor of losing important money cannot be conveyed by literature. Art cannot convey an inexperienced girl. Would it is like to be a wife and a mother? There are certain things that cannot be adequately explained to a virgin by their words or pictures. Nor can any description that I might offer here even approximate what it might feel like to lose a real chunk of money they use to own. It's tough because finance is way more about emotions than spreadsheets. So you could try to educate this person and I think that can help, but since no one teaches this stuff, it's probably better to ease into it and look at this from a psychological framework. So no one gets off the couch on day one who's never jagged in their life runs a marathon. You have to ease into it and train and get better. So the way I view it is the good strategy you can stick with is vastly superior to the great strategy that you can't stick with. So I think you can start by asking some questions. To this person, how do you plan on retiring if your portfolio is going to trail inflation every year? Does your current advisor actually understand your time horizon and risk profile? And do you understand how the stock market works? If this person doesn't, there's no shame in that. I think there is a great way to learn in one of my favorite books in this topic. Little wealth and inevitable wealth by Nick Murray is a classic one of the best books I've ever read on getting a long term mindset and thinking through investing in this stock market. Now, if you want to buy this book for your friend, you can't actually get it on Amazon. You have to go to Nick Murray.com. That's M-U-R-R-A-Y because Nick sells these books himself. He printed it on his own and Nick is a not a businessman. He's a business common man. So that's a great book to check out to teach someone like this. What do we think Duncan? Yeah, no, it sounds good. I've got to read that one. I haven't read that one yet. It's a classic one. It sounds like what your time is all about the very idea of risk tolerance, right? Just figuring out what someone's willing to put  ...

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (3.42.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (5.1.1)
# Requirement already satisfied: fastapi in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.103.2)
# Requirement already satisfied: ffmpy in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.5.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: httpx in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.24.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.16.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.24.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.9.5)
# Requirement already satisfied: packaging in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.0.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (9.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.10.12)
# Requirement already satisfied: pydub in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (4.7.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio) (11.0.3)
# Requirement already satisfied: fsspec in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==0.5.0->gradio) (2023.6.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.0)
# Requirement already satisfied: toolz in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.14.0->gradio) (4.66.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.0->gradio) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.0->gradio) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.0->gradio) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click>=7.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from uvicorn>=0.14.0->gradio) (8.1.6)
# Requirement already satisfied: h11>=0.8 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from httpx->gradio) (0.17.3)
# Requirement already satisfied: sniffio in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.2)
# Requirement already satisfied: colorama in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from click>=7.0->uvicorn>=0.14.0->gradio) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.2)
# Requirement already satisfied: six>=1.5 in c:\users\thame\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import gradio as gr
import openai

# %%
context = "At interest rates so low, should I instead take a loan, finance the house and invest my capital in the stock market? So last but not least, I'm in my 30s and can now afford to buy a house full cash without taking any debt. However, with interest rates so low and they wrote this one a while back, but should I take a loan anyway and finance the house and invest my capital in the stock market? I think this is interesting that rates could change the story. Going from a 3% mortgage rate to a 5% that hurdle changes. So nine months ago, I would have said you'd be nuts to pay full cash now. Maybe it kind of makes sense, but first of all, who does this person for having that amount of money? I don't really live to be able to buy and cash, but that's great. But so Matt, you're thinking through this type of decision with a client. And this is the kind of thing where there really is no right or wrong answer, right? A lot of this is personality driven and depending on what the person wants to get"

def answer_question(question):
    prompt = f"""Answer the following question using only the context below. Answer in the style of Ben Carlson, a financial advisor, and podcaster.

Context:
{context}

Q: {question}
A:"""

    # Specify the GPT-3.5-turbo model when making the API request
    response = openai.Completion.create(
        engine="text-davinci-004",  # Specify the GPT-3.5-turbo engine
        prompt=prompt,
        temperature=0.7,
        max_tokens=500,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )["choices"][0]["text"].strip(" \n")

    return response

iface = gr.Interface(fn=answer_question, inputs="text", outputs="text", live=True, title="Financial Advisor Q&A")
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\networking.py:228, in setup_tunnel(local_host, local_port, share_token)
#     225 tunnel = Tunnel(
#     226     remote_host, remote_port, local_host, local_port, share_token
#     227 )
# --> 228 address = tunnel.start_tunnel()
#     229 return address
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\tunneling.py:59, in Tunnel.start_tunnel(self)
#      58 self.download_binary()
# ---> 59 self.url = self._start_tunnel(BINARY_PATH)
#      60 return self.url
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\tunneling.py:87, in Tunnel._start_tunnel(self, binary)
#      70 command = [
#      71     binary,
#      72     "http",
#    (...)
#      85     "--disable_log_color",
#      86 ]
# ---> 87 self.proc = subprocess.Popen(
#      88     command, stdout=subprocess.PIPE, stderr=subprocess.PIPE
#      89 )
#      90 atexit.register(self.kill)
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1435, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1434 try:
# -> 1435     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1436                              # no special security
#    1437                              None, None,
#    1438                              int(not close_fds),
#    1439                              creationflags,
#    1440                              env,
#    1441                              cwd,
#    1442                              startupinfo)
#    1443 finally:
#    1444     # Child is launched. Close the parent's copy of those pipe
#    1445     # handles that only the child should have open.  You need
#    (...)
#    1448     # pipe will not close when the child process exits and the
#    1449     # ReadFile will hang.
#
# OSError: [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\blocks.py:2005, in Blocks.launch(self, inline, inbrowser, share, debug, enable_queue, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, show_tips, height, width, encrypt, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, file_directories, allowed_paths, blocked_paths, root_path, _frontend, app_kwargs)
#    2004 if self.share_url is None:
# -> 2005     self.share_url = networking.setup_tunnel(
#    2006         self.server_name, self.server_port, self.share_token
#    2007     )
#    2008 print(strings.en["SHARE_LINK_DISPLAY"].format(self.share_url))
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\networking.py:231, in setup_tunnel(local_host, local_port, share_token)
#     230     except Exception as e:
# --> 231         raise RuntimeError(str(e)) from e
#     232 raise RuntimeError("Could not get share link from Gradio API Server.")
#
# RuntimeError: [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[52], line 26
#      23     return response
#      25 iface = gr.Interface(fn=answer_question, inputs="text", outputs="text", live=True, title="Financial Advisor Q&A")
# ---> 26 iface.launch(share=True)
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\site-packages\gradio\blocks.py:2016, in Blocks.launch(self, inline, inbrowser, share, debug, enable_queue, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, show_tips, height, width, encrypt, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, file_directories, allowed_paths, blocked_paths, root_path, _frontend, app_kwargs)
#    2014 self.share_url = None
#    2015 self.share = False
# -> 2016 if Path(BINARY_PATH).exists():
#    2017     print(strings.en["COULD_NOT_GET_SHARE_LINK"])
#    2018 else:
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\pathlib.py:1288, in Path.exists(self)
#    1284 """
#    1285 Whether this path exists.
#    1286 """
#    1287 try:
# -> 1288     self.stat()
#    1289 except OSError as e:
#    1290     if not _ignore_error(e):
#
# File c:\Users\thame\AppData\Local\Programs\Python\Python310\lib\pathlib.py:1095, in Path.stat(self, follow_symlinks)
#    1090 def stat(self, *, follow_symlinks=True):
#    1091     """
#    1092     Return the result of the stat() system call on this path, like
#    1093     os.stat() does.
#    1094     """
# -> 1095     return self._accessor.stat(self, follow_symlinks=follow_symlinks)
#
# OSError: [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software: 'c:\\Users\\thame\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\gradio\\frpc_windows_amd64_v0.2'
